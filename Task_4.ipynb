# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Load the dataset
data = pd.read_csv('cleaned_diabetes_data.csv')

# Assuming 'class' column is categorical and needs encoding
y = data['class'].values
X = data.drop('class', axis=1).values

# One-hot encoding the labels
encoder = OneHotEncoder(sparse=False)
y_encoded = encoder.fit_transform(y.reshape(-1, 1))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.20, random_state=42)

# Build the neural network model
model = Sequential([
    Dense(64, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(32, activation='relu'),
    Dense(y_encoded.shape[1], activation='softmax')  # Output layer nodes equal to number of classes
])

# Compile the model
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/50
# 20/20 [==============================] - 2s 17ms/step - loss: 1.1206 - accuracy: 0.7141 - val_loss: 0.8320 - val_accuracy: 0.8188
# Epoch 2/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6202 - accuracy: 0.8391 - val_loss: 0.5896 - val_accuracy: 0.8188
# Epoch 3/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4431 - accuracy: 0.8391 - val_loss: 0.5017 - val_accuracy: 0.8188
# Epoch 4/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3643 - accuracy: 0.8578 - val_loss: 0.4539 - val_accuracy: 0.8500
# Epoch 5/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3153 - accuracy: 0.8906 - val_loss: 0.4260 - val_accuracy: 0.8625
# Epoch 6/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2795 - accuracy: 0.8984 - val_loss: 0.4123 - val_accuracy: 0.8625
# Epoch 7/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.2561 - accuracy: 0.9016 - val_loss: 0.4038 - val_accuracy: 0.8687
# Epoch 8/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2413 - accuracy: 0.9031 - val_loss: 0.4016 - val_accuracy: 0.8625
# Epoch 9/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.2269 - accuracy: 0.9078 - val_loss: 0.4000 - val_accuracy: 0.8625
# Epoch 10/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2144 - accuracy: 0.9156 - val_loss: 0.3982 - val_accuracy: 0.8687
# Epoch 11/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.2060 - accuracy: 0.9234 - val_loss: 0.3979 - val_accuracy: 0.8562
# Epoch 12/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1964 - accuracy: 0.9297 - val_loss: 0.3991 - val_accuracy: 0.8562
# Epoch 13/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1886 - accuracy: 0.9328 - val_loss: 0.3994 - val_accuracy: 0.8562
# Epoch 14/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1819 - accuracy: 0.9328 - val_loss: 0.4007 - val_accuracy: 0.8625
# Epoch 15/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1747 - accuracy: 0.9391 - val_loss: 0.3994 - val_accuracy: 0.8625
# Epoch 16/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1683 - accuracy: 0.9406 - val_loss: 0.4027 - val_accuracy: 0.8750
# Epoch 17/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1626 - accuracy: 0.9406 - val_loss: 0.4050 - val_accuracy: 0.8625
# Epoch 18/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1572 - accuracy: 0.9469 - val_loss: 0.4051 - val_accuracy: 0.8687
# Epoch 19/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1523 - accuracy: 0.9500 - val_loss: 0.4061 - val_accuracy: 0.8750
# Epoch 20/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1477 - accuracy: 0.9500 - val_loss: 0.4049 - val_accuracy: 0.8687
# Epoch 21/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1412 - accuracy: 0.9563 - val_loss: 0.4063 - val_accuracy: 0.8750
# Epoch 22/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1376 - accuracy: 0.9563 - val_loss: 0.4117 - val_accuracy: 0.8625
# Epoch 23/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1344 - accuracy: 0.9578 - val_loss: 0.4127 - val_accuracy: 0.8750
# Epoch 24/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1329 - accuracy: 0.9531 - val_loss: 0.4168 - val_accuracy: 0.8875
# Epoch 25/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1257 - accuracy: 0.9563 - val_loss: 0.4127 - val_accuracy: 0.8625
# Epoch 26/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1236 - accuracy: 0.9594 - val_loss: 0.4104 - val_accuracy: 0.8750
# Epoch 27/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1199 - accuracy: 0.9641 - val_loss: 0.4178 - val_accuracy: 0.8813
# Epoch 28/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1157 - accuracy: 0.9641 - val_loss: 0.4131 - val_accuracy: 0.8875
# Epoch 29/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1134 - accuracy: 0.9641 - val_loss: 0.4159 - val_accuracy: 0.8813
# Epoch 30/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1098 - accuracy: 0.9672 - val_loss: 0.4184 - val_accuracy: 0.8875
# Epoch 31/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9719 - val_loss: 0.4236 - val_accuracy: 0.8813
# Epoch 32/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1034 - accuracy: 0.9703 - val_loss: 0.4270 - val_accuracy: 0.8875
# Epoch 33/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1006 - accuracy: 0.9719 - val_loss: 0.4180 - val_accuracy: 0.8750
# Epoch 34/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0987 - accuracy: 0.9750 - val_loss: 0.4239 - val_accuracy: 0.8750
# Epoch 35/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.9750 - val_loss: 0.4276 - val_accuracy: 0.8750
# Epoch 36/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0925 - accuracy: 0.9750 - val_loss: 0.4339 - val_accuracy: 0.8813
# Epoch 37/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0912 - accuracy: 0.9750 - val_loss: 0.4291 - val_accuracy: 0.8875
# Epoch 38/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0891 - accuracy: 0.9766 - val_loss: 0.4381 - val_accuracy: 0.8875
# Epoch 39/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0863 - accuracy: 0.9781 - val_loss: 0.4361 - val_accuracy: 0.8813
# Epoch 40/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0831 - accuracy: 0.9766 - val_loss: 0.4418 - val_accuracy: 0.8813
# Epoch 41/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0823 - accuracy: 0.9766 - val_loss: 0.4398 - val_accuracy: 0.8813
# Epoch 42/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0806 - accuracy: 0.9766 - val_loss: 0.4472 - val_accuracy: 0.8813
# Epoch 43/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0773 - accuracy: 0.9781 - val_loss: 0.4376 - val_accuracy: 0.8813
# Epoch 44/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0762 - accuracy: 0.9766 - val_loss: 0.4448 - val_accuracy: 0.8813
# Epoch 45/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0746 - accuracy: 0.9797 - val_loss: 0.4447 - val_accuracy: 0.8813
# Epoch 46/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0718 - accuracy: 0.9766 - val_loss: 0.4453 - val_accuracy: 0.8875
# Epoch 47/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0689 - accuracy: 0.9781 - val_loss: 0.4473 - val_accuracy: 0.8813
# Epoch 48/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9797 - val_loss: 0.4525 - val_accuracy: 0.8875
# Epoch 49/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0677 - accuracy: 0.9797 - val_loss: 0.4563 - val_accuracy: 0.8875
# Epoch 50/50
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0645 - accuracy: 0.9797 - val_loss: 0.4583 - val_accuracy: 0.8875
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2403 - accuracy: 0.9350
