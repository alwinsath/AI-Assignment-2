# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Load the dataset
data = pd.read_csv('cleaned_diabetes_data.csv')

# Assuming 'class' column is categorical and needs encoding
y = data['class'].values
X = data.drop('class', axis=1).values

# One-hot encoding the labels
encoder = OneHotEncoder(sparse=False)
y_encoded = encoder.fit_transform(y.reshape(-1, 1))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.20, random_state=42)

# Build the neural network model
model = Sequential([
    Dense(64, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(32, activation='relu'),
    Dense(y_encoded.shape[1], activation='softmax')  # Output layer nodes equal to number of classes
])

# Compile the model
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)

# Predict the labels for the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)

# Calculate accuracy and precision
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')

print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Test loss: {test_loss}")
print(f"Test accuracy: {test_accuracy}")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/50
# 20/20 [==============================] - 4s 34ms/step - loss: 1.3765 - accuracy: 0.5000 - val_loss: 1.1269 - val_accuracy: 0.8250
# Epoch 2/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.9354 - accuracy: 0.8750 - val_loss: 0.7808 - val_accuracy: 0.8500
# Epoch 3/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6195 - accuracy: 0.8531 - val_loss: 0.5881 - val_accuracy: 0.8250
# Epoch 4/50
# 20/20 [==============================] - 0s 17ms/step - loss: 0.4501 - accuracy: 0.8641 - val_loss: 0.4998 - val_accuracy: 0.8625
# Epoch 5/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3628 - accuracy: 0.8953 - val_loss: 0.4518 - val_accuracy: 0.8687
# Epoch 6/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.3072 - accuracy: 0.9016 - val_loss: 0.4202 - val_accuracy: 0.8562
# Epoch 7/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.2686 - accuracy: 0.9109 - val_loss: 0.4028 - val_accuracy: 0.8687
# Epoch 8/50
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2413 - accuracy: 0.9187 - val_loss: 0.3948 - val_accuracy: 0.8687
# Epoch 9/50
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2208 - accuracy: 0.9297 - val_loss: 0.3910 - val_accuracy: 0.8750
# Epoch 10/50
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2064 - accuracy: 0.9312 - val_loss: 0.3849 - val_accuracy: 0.8687
# Epoch 11/50
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1952 - accuracy: 0.9312 - val_loss: 0.3827 - val_accuracy: 0.8687
# Epoch 12/50
# 20/20 [==============================] - 0s 14ms/step - loss: 0.1872 - accuracy: 0.9438 - val_loss: 0.3833 - val_accuracy: 0.8750
# Epoch 13/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1786 - accuracy: 0.9406 - val_loss: 0.3803 - val_accuracy: 0.8750
# Epoch 14/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1714 - accuracy: 0.9438 - val_loss: 0.3771 - val_accuracy: 0.8750
# Epoch 15/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1656 - accuracy: 0.9422 - val_loss: 0.3776 - val_accuracy: 0.8750
# Epoch 16/50
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1590 - accuracy: 0.9484 - val_loss: 0.3790 - val_accuracy: 0.8813
# Epoch 17/50
# 20/20 [==============================] - 0s 15ms/step - loss: 0.1535 - accuracy: 0.9484 - val_loss: 0.3840 - val_accuracy: 0.8750
# Epoch 18/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1485 - accuracy: 0.9516 - val_loss: 0.3859 - val_accuracy: 0.8750
# Epoch 19/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1438 - accuracy: 0.9547 - val_loss: 0.3872 - val_accuracy: 0.8750
# Epoch 20/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1420 - accuracy: 0.9516 - val_loss: 0.3844 - val_accuracy: 0.8813
# Epoch 21/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1368 - accuracy: 0.9500 - val_loss: 0.3858 - val_accuracy: 0.8813
# Epoch 22/50
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1313 - accuracy: 0.9563 - val_loss: 0.3806 - val_accuracy: 0.8875
# Epoch 23/50
# 20/20 [==============================] - 0s 11ms/step - loss: 0.1282 - accuracy: 0.9578 - val_loss: 0.3879 - val_accuracy: 0.8875
# Epoch 24/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1247 - accuracy: 0.9609 - val_loss: 0.3880 - val_accuracy: 0.8875
# Epoch 25/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1205 - accuracy: 0.9578 - val_loss: 0.3904 - val_accuracy: 0.8813
# Epoch 26/50
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1164 - accuracy: 0.9625 - val_loss: 0.3952 - val_accuracy: 0.8813
# Epoch 27/50
# 20/20 [==============================] - 0s 14ms/step - loss: 0.1129 - accuracy: 0.9625 - val_loss: 0.3934 - val_accuracy: 0.8750
# Epoch 28/50
# 20/20 [==============================] - 0s 16ms/step - loss: 0.1103 - accuracy: 0.9625 - val_loss: 0.3924 - val_accuracy: 0.8875
# Epoch 29/50
# 20/20 [==============================] - 0s 11ms/step - loss: 0.1084 - accuracy: 0.9625 - val_loss: 0.3933 - val_accuracy: 0.8813
# Epoch 30/50
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1053 - accuracy: 0.9656 - val_loss: 0.3936 - val_accuracy: 0.8813
# Epoch 31/50
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1027 - accuracy: 0.9688 - val_loss: 0.3934 - val_accuracy: 0.8875
# Epoch 32/50
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0998 - accuracy: 0.9703 - val_loss: 0.4001 - val_accuracy: 0.8813
# Epoch 33/50
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0983 - accuracy: 0.9734 - val_loss: 0.3999 - val_accuracy: 0.8813
# Epoch 34/50
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0964 - accuracy: 0.9688 - val_loss: 0.4029 - val_accuracy: 0.8813
# Epoch 35/50
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0927 - accuracy: 0.9734 - val_loss: 0.4028 - val_accuracy: 0.8938
# Epoch 36/50
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0915 - accuracy: 0.9719 - val_loss: 0.4026 - val_accuracy: 0.9000
# Epoch 37/50
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0877 - accuracy: 0.9797 - val_loss: 0.4031 - val_accuracy: 0.8938
# Epoch 38/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0859 - accuracy: 0.9781 - val_loss: 0.4073 - val_accuracy: 0.9000
# Epoch 39/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0851 - accuracy: 0.9734 - val_loss: 0.4134 - val_accuracy: 0.9062
# Epoch 40/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0832 - accuracy: 0.9797 - val_loss: 0.4054 - val_accuracy: 0.8938
# Epoch 41/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0821 - accuracy: 0.9766 - val_loss: 0.4168 - val_accuracy: 0.9062
# Epoch 42/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0791 - accuracy: 0.9844 - val_loss: 0.4195 - val_accuracy: 0.8938
# Epoch 43/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0762 - accuracy: 0.9828 - val_loss: 0.4130 - val_accuracy: 0.9125
# Epoch 44/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0740 - accuracy: 0.9812 - val_loss: 0.4199 - val_accuracy: 0.9062
# Epoch 45/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0722 - accuracy: 0.9828 - val_loss: 0.4230 - val_accuracy: 0.9062
# Epoch 46/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0702 - accuracy: 0.9828 - val_loss: 0.4170 - val_accuracy: 0.9062
# Epoch 47/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0692 - accuracy: 0.9812 - val_loss: 0.4215 - val_accuracy: 0.9062
# Epoch 48/50
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0681 - accuracy: 0.9844 - val_loss: 0.4241 - val_accuracy: 0.9062
# Epoch 49/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0652 - accuracy: 0.9844 - val_loss: 0.4307 - val_accuracy: 0.9062
# Epoch 50/50
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0634 - accuracy: 0.9828 - val_loss: 0.4286 - val_accuracy: 0.9062
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2435 - accuracy: 0.9250
# 7/7 [==============================] - 0s 4ms/step
# Confusion Matrix:
# [[ 16   2   3   0]
#  [  1   3   2   0]
#  [  3   3 166   0]
#  [  0   0   1   0]]
# Test loss: 0.24348536133766174
# Test accuracy: 0.925000011920929
# Accuracy: 0.925
# Precision: 0.92525
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
